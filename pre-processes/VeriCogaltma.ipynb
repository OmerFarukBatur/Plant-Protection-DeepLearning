# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import random
from skimage import exposure
from skimage.util import random_noise
from skimage import transform
from cv2 import resize
from skimage import transform
import os
from skimage import io
import cv2
import pandas as pd
import time
from scipy import ndimage

# %%
img=mpimg.imread('D:\\Bitirme Projesi\\X_test\\7_BademIcKurdu.jpg')
plt.imshow(img)
img_rescale=resize(img,(166,303))
plt.imshow(img_rescale)

# %%
horiz=np.fliplr(img_rescale)
plt.imshow(horiz)

# %%
vert=np.flipud(img_rescale)
plt.imshow(vert)

# %%
from skimage import transform

# %%
trans=transform.rotate(img_rescale,random.uniform(-45,45))
new_file_path='D:\\Bitirme Projesi\\Deneme\\'+str(trans)+'_imgnos.jpg'
cv2.imwrite(new_file_path, trans)
plt.imshow(trans)

# %%
img_nos=random_noise(img,mode='s&p', seed=0, clip=True)
plt.imshow(img_nos)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)
    horiz=np.fliplr(img)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_horiz.jpg'
    cv2.imwrite(new_file_path, horiz)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)
    vert=np.flipud(img)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_vert.jpg'
    cv2.imwrite(new_file_path, vert)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)         
    height, width = img.shape[:2]  
    quarter_height, quarter_width = height / 4, width / 4  
    T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])  
    img_translation = cv2.warpAffine(img, T, (width, height))
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_translation.jpg'
    cv2.imwrite(new_file_path, img_translation)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)
    ksize = (5, 5)
    image = cv2.blur(img, ksize)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_blur.jpg'
    cv2.imwrite(new_file_path, image)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)
    trans30=ndimage.rotate(img, 30)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans30.jpg'
    cv2.imwrite(new_file_path, trans30)
    trans60=ndimage.rotate(img, 60)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans60.jpg'
    cv2.imwrite(new_file_path, trans60)
    trans90=ndimage.rotate(img, 90)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans90.jpg'
    cv2.imwrite(new_file_path, trans90)
    trans150=ndimage.rotate(img, 150)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans150.jpg'
    cv2.imwrite(new_file_path, trans150)
    trans180=ndimage.rotate(img, 180)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans180.jpg'
    cv2.imwrite(new_file_path, trans180)
    trans210=ndimage.rotate(img, 210)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans210.jpg'
    cv2.imwrite(new_file_path, trans210)
    trans240=ndimage.rotate(img, 240)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans240.jpg'
    cv2.imwrite(new_file_path, trans240)
    trans270=ndimage.rotate(img, 270)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans270.jpg'
    cv2.imwrite(new_file_path, trans270)
    trans300=ndimage.rotate(img, 300)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans300.jpg'
    cv2.imwrite(new_file_path, trans300)
    trans330=ndimage.rotate(img, 330)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans330.jpg'
    cv2.imwrite(new_file_path, trans330)

# %%
import cv2
import numpy as np
from skimage.util import random_noise
 
img = cv2.imread("D:\\Bitirme Projesi\\X_test\\7_BademIcKurdu.jpg")
noise_img = random_noise(img, mode='s&p',amount=0.1)
noise_img = np.array(255*noise_img, dtype = 'uint8')
plt.imshow(noise_img)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_test")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_test\\"+i)
    img_nos=random_noise(img, mode='s&p',amount=0.1)
    noise_img = np.array(255*img_nos, dtype = 'uint8')
    new_file_path='D:\\Bitirme Projesi\\Deneme_1\\'+str(i)+'_imgnos.jpg'
    cv2.imwrite(new_file_path, img_nos)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_test")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_test\\"+i)
    i=i.split('.')[0]
    horiz=np.fliplr(img)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_horiz.jpg'
    cv2.imwrite(new_file_path, horiz)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_test")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_test\\"+i)
    i=i.split('.')[0]
    horiz=np.fliplr(img)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_horiz.jpg'
    cv2.imwrite(new_file_path, horiz)
    vert=np.flipud(img)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_vert.jpg'
    cv2.imwrite(new_file_path, vert)        
    height, width = img.shape[:2]  
    quarter_height, quarter_width = height / 4, width / 4  
    T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])  
    img_translation = cv2.warpAffine(img, T, (width, height))
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_translation.jpg'
    cv2.imwrite(new_file_path, img_translation)
    ksize = (5, 5)
    image = cv2.blur(img, ksize)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_blur.jpg'
    cv2.imwrite(new_file_path, image)
    trans30=ndimage.rotate(img, 30)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans30.jpg'
    cv2.imwrite(new_file_path, trans30)
    trans60=ndimage.rotate(img, 60)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans60.jpg'
    cv2.imwrite(new_file_path, trans60)
    trans90=ndimage.rotate(img, 90)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans90.jpg'
    cv2.imwrite(new_file_path, trans90)
    trans150=ndimage.rotate(img, 150)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans150.jpg'
    cv2.imwrite(new_file_path, trans150)
    trans180=ndimage.rotate(img, 180)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans180.jpg'
    cv2.imwrite(new_file_path, trans180)
    trans210=ndimage.rotate(img, 210)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans210.jpg'
    cv2.imwrite(new_file_path, trans210)
    trans240=ndimage.rotate(img, 240)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans240.jpg'
    cv2.imwrite(new_file_path, trans240)
    trans270=ndimage.rotate(img, 270)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans270.jpg'
    cv2.imwrite(new_file_path, trans270)
    trans300=ndimage.rotate(img, 300)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans300.jpg'
    cv2.imwrite(new_file_path, trans300)
    trans330=ndimage.rotate(img, 330)
    new_file_path='D:\\Bitirme Projesi\\X_test_CogaltilmisVeri\\'+str(i)+'_trans330.jpg'
    cv2.imwrite(new_file_path, trans330)

# %%
data=os.listdir("D:\\Bitirme Projesi\\X_train")
for i in data:
    img=cv2.imread("D:\\Bitirme Projesi\\X_train\\"+i)
    i=i.split('.')[0]
    horiz=np.fliplr(img)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_horiz.jpg'
    cv2.imwrite(new_file_path, horiz)
    vert=np.flipud(img)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_vert.jpg'
    cv2.imwrite(new_file_path, vert)        
    height, width = img.shape[:2]  
    quarter_height, quarter_width = height / 4, width / 4  
    T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])  
    img_translation = cv2.warpAffine(img, T, (width, height))
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_translation.jpg'
    cv2.imwrite(new_file_path, img_translation)
    ksize = (5, 5)
    image = cv2.blur(img, ksize)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_blur.jpg'
    cv2.imwrite(new_file_path, image)
    trans30=ndimage.rotate(img, 30)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans30.jpg'
    cv2.imwrite(new_file_path, trans30)
    trans60=ndimage.rotate(img, 60)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans60.jpg'
    cv2.imwrite(new_file_path, trans60)
    trans90=ndimage.rotate(img, 90)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans90.jpg'
    cv2.imwrite(new_file_path, trans90)
    trans150=ndimage.rotate(img, 150)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans150.jpg'
    cv2.imwrite(new_file_path, trans150)
    trans180=ndimage.rotate(img, 180)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans180.jpg'
    cv2.imwrite(new_file_path, trans180)
    trans210=ndimage.rotate(img, 210)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans210.jpg'
    cv2.imwrite(new_file_path, trans210)
    trans240=ndimage.rotate(img, 240)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans240.jpg'
    cv2.imwrite(new_file_path, trans240)
    trans270=ndimage.rotate(img, 270)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans270.jpg'
    cv2.imwrite(new_file_path, trans270)
    trans300=ndimage.rotate(img, 300)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans300.jpg'
    cv2.imwrite(new_file_path, trans300)
    trans330=ndimage.rotate(img, 330)
    new_file_path='D:\\Bitirme Projesi\\X_train_CogaltilmisVeri\\'+str(i)+'_trans330.jpg'
    cv2.imwrite(new_file_path, trans330)
